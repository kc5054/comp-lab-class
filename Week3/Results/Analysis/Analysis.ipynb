# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data=pd.read_csv('density.xvg',header=0,names=['Time','density'],skiprows=29,sep='\s+')
data['Time']/=1000
data.plot(x='Time',y='density')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data1=pd.read_csv('potential.xvg',header=0,names=['Time','potential'],skiprows=29,sep='\s+')
data1['Time']/=1000
data1.plot(x='Time',y='potential')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data2=pd.read_csv('pressure.xvg',header=0,names=['Time','pressure'],skiprows=29,sep='\s+')
data2['Time']/=1000
data2.plot(x='Time',y='pressure')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data3=pd.read_csv('rmsd.xvg',header=0,names=['Time','rmsd'],skiprows=29,sep='\s+')
data3.plot(x='Time',y='rmsd')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data4=pd.read_csv('rmsd_xtal.xvg',header=0,names=['Time','rmsd_xtal'],skiprows=29,sep='\s+')
data4.plot(x='Time',y='rmsd_xtal')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data5=pd.read_csv('temperature.xvg',header=0,names=['Time','temperature'],skiprows=29,sep='\s+')
data['Time']/=1000
data5.plot(x='Time',y='temperature')
# Out:
# <AxesSubplot:xlabel='Time'>

# %%
data6=pd.read_csv('gyrate.xvg',header=0,names=['Time','gyrate','rx','ry','rz'],skiprows=29,sep='\s+')
data6['Time']/=1000
data6.plot(x='Time',y='gyrate')
# Out:
# <AxesSubplot:xlabel='Time'>
