# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
rcData=np.loadtxt('/home/kc5054/CHEM2671/comp-lab-class/Week13/Outputs/monitor/MONITOR-COLVAR.metadynLog',skiprows=189)

# %%
rc=rcData[:,1]
time=rcData[:,0]
time=np.asarray(time)

# %%
fig,ax=plt.subplots()
ax.plot(time/1000,rc)
ax.set_xlabel('time (ns)')
ax.set_ylabel('d(C-C)-d(C-O)')
ax.set_title('Reaction Coordinates - Time')
# Out:
# Text(0.5, 1.0, 'Reaction Coordinates - Time')
