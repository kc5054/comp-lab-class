# %%
import numpy as np
import matplotlib.pyplot as plt
import mdtraj as md
import pandas as pd
import matplotlib as mpl
import math

# %%
trj=md.load_trr("adp_exchange4temps.trr",top='adp_exchange4temps.gro')

# %%
psi=md.compute_psi(trj)
phi=md.compute_phi(trj)

# %%
H,xedges,yedges=np.histogram2d(psi[1].flatten(),phi[1].flatten(),bins=100)
H=-np.log(H)
H=H-np.min(H)
fig,ax=plt.subplots()
plt.imshow(H,extent=[xedges[0],xedges[-1],yedges[0],yedges[-1]])
ax.set_title('Free energy surface')
ax.set_aspect(2)
plt.xlabel('psi')
plt.ylabel('phi')
plt.colorbar()
plt.show
# Out:
# <ipython-input-5-5a13aeea0d61>:2: RuntimeWarning: divide by zero encountered in log
#   H=-np.log(H)
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('replica_temp.xvg',header=0,names=['Time','Index1','Index2','Index3','Index4'],sep='\s+')

# %%
time=[] #unit is ns
t1=[]
t2=[]
t3=[]
t4=[]
for i in range (50000):
    if((i+1)%100==0):
        time.append(data['Time']/1000)
        t1.append(data['Index1']*50+300)
        t2.append(data['Index2']*50+300)
        t3.append(data['Index3']*50+300)
        t4.append(data['Index4']*50+300)

# %%
fig,ax=plt.subplot()
ax.plot(time,t1,label='Replica 1')
ax.plot(time,t2,label='Replica 2')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c2a6a4371305> in <module>
# ----> 1 fig,ax=plt.subplot()
#       2 ax.plot(time,t1,label='Replica 1')
#       3 ax.plot(time,t2,label='Replica 2')
#
# NameError: name 'plt' is not defined
