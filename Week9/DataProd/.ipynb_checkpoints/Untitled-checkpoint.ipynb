# %%
import matplotlib.pyplot as plt
import numpy as np
import MDAnalysis as md

# %%
Tlist=[1.5,1.0,0.9,0.8,0.7,0.65,0.6,0.55,0.5,0.475]
N=[10000,50000,150000,150000,180000,350000,1000000,3000000,10000000,30000000]
Trajectories=[]
traj = md.Universe("/home/kc5054/CHEM2671/comp-lab-class/Week9/DataProd/equil/kalj_T1.5_n360_v300_50000_1.lammpstrj", '/home/kc5054/CHEM2671/comp-lab-class/Week9/DataProd/prod/kalj_T1.5_n360_v300_prod_10000_1.unwrap.dcd', topology_format="LAMMPSDUMP")
for T in Tlist:
    traj = md.Universe(f'/equil/kalj_T{T}_n360_v300_50000_1.lammpstrj', f'/prod/kalj_T{T}_n360_v300_prod_10000_1.unwrap.dcd', format="LAMMPS")
    #print(f'kalj_T{T}_n360_v300_50000_1.lammpstrj')
    Trajectories.append(traj)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In [26], line 4
#       3 Trajectories=[]
# ----> 4 traj = md.Universe("/home/kc5054/CHEM2671/comp-lab-class/Week9/DataProd/equil/kalj_T1.5_n360_v300_50000_1.lammpstrj", '/home/kc5054/CHEM2671/comp-lab-class/Week9/DataProd/prod/kalj_T1.5_n360_v300_prod_10000_1.unwrap.dcd', topology_format="LAMMPSDUMP")
#       5 for T in Tlist:
#
# File /ext3/miniconda3/lib/python3.9/site-packages/MDAnalysis/core/universe.py:346, in Universe.__init__(self, topology, all_coordinates, format, topology_format, transformations, guess_bonds, vdwradii, in_memory, in_memory_step, *coordinates, **kwargs)
#     345     self.filename = _check_file_like(topology)
# --> 346     topology = _topology_from_file_like(self.filename,
#     347                                         topology_format=topology_format,
# ...

# %%
print(Trajectories)
# Out:
# []
